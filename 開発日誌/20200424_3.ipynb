# %%
"""
#このスクリプトの説明
旧AE‗old.py  
AE.pyの機能をスクリプトベースに移植したもの  

AE.pyがオブジェクト指向化して
Jupyter等での動作・機能検証が難しくなったため作成
→AE.pyの機能拡張に連動してメンテ要
 メンテ記録は最下行参照
"""


#%%
# cording = UTF-8
import os,re,random,copy
import scipy,librosa
import numpy as np
import pandas as pd             #ほとんど使わんけど
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import sklearn

####################################初期化####################################
aug_amount = 100        #ファイルごとのAugmentationの回数
lr = 0.01               #初期学習率
alpha = 1e-05           #L2正則化の係数
dr_rate = 0.3           #ドロップアウト率
batch_size = 50         #オフライン学習時のバッチサイズ
epochs = 100            #学習時のエポック数(グリッドサーチ時は無効)
monitor = "val_loss"    #学習率減衰/早期打ち切りの指標
encode_dim = 500        #オートエンコーダの圧縮次元
n_components = 0.999    #疑似AEの保持分散

#ディレクトリの初期化
base_dir = "../"
data_dir =os.path.join(base_dir,"data")
ok_dir = os.path.join(data_dir,"OK")
ng_dir = os.path.join(data_dir,"NG")
env_dir = os.path.join(data_dir,"environment")
log_dir = "./logs"       #Tensorboardログの保存パス
modeldir = "./models"   #学習済みモデルの保存パス

#学習用データファイル
datafile = "dataset3.npz"

####################################関数定義###################################

#対象ディレクトリのファイル一覧を取得
def get_file_list(dir):
    path = dir
    file_list = os.listdir(path)
    print("get file_list :{}".format(file_list))
    return file_list

#対象ディレクトリの最大ファイルをサーチ
def wav_search(dir,f_list):
    #呼び出されるごとに初期化する
    wave_list = []
    file_size = 0
    
    return_path = os.path.abspath('./')
    
    os.chdir(dir)
    for i in f_list:
        search_index = re.search('.wav',i)
        if search_index:
            wave_list .append(i)
            if os.path.getsize(i) > file_size:
                file_size = os.path.getsize(i)
                largest_file = i
        
    os.chdir(return_path)   #カレントディレクトリを戻す
    print("get file :{0} ,file size:{1}"\
        .format(largest_file,file_size))
    return wave_list,largest_file,file_size

#オーディオファイルの読み込み サンプルレート22.05kHz、モノラルで固定
def load_wav(dir,file):
    #呼び出されるごとに初期化する
    wf = np.arange(0)

    f_path = os.path.join(dir,file)
    wf,sp_rate = librosa.load(f_path,sr=22050,mono = True)
    del sp_rate
    return wf

#スペクトログラムの取得 パワースペクトラムのまま処理するならlibrosa不要
def get_spg(wf):
    spg = np.arange(0)
    sp_f,sp_t,spg = scipy.signal.spectrogram(wf,fs=22050,
        window = np.hamming(1024),nfft =1024)
#    spg = librosa.power_to_db(spg)
    spg =spg.astype('float16')
    return sp_f,sp_t,spg

#Augmentationの処理
def aug_process(frame,dir,wave_list,env_file,):
    #呼び出されるごとに初期化する
    length = 0
    count = 0
    wf = np.arange(0)

    length = int(frame * 1.2)
    for i in wave_list:
        wf = load_wav(dir,i)
        for j in range(aug_amount):
            start = random.randint(0,len(env_file)-length)
            aug_wav = copy.deepcopy(env_file[start : start + length])
            del start
            start = random.randint(0,len(aug_wav) - len(wf))
            aug_wav = aug_wav + random.gauss(1,0.05)
            aug_wav[ start:start + len(wf) ] = \
                aug_wav[ start : start + len(wf) ] + wf
            sp_f,sp_t,spg = get_spg(aug_wav)
            spg = spg.reshape(1,len(sp_f),len(sp_t))
            try:
                X_data
            except:
                X_data = copy.deepcopy(spg)
            else:
                X_data = np.vstack((X_data,spg))
            del start,aug_wav,sp_f,sp_t,spg
            count = count + 1
        del wf
        print("Augmentation done! total count = {}".format(count))

    return X_data

#データセットの作成 ここまでの関数は全部ここに集約される
#最大ファイルサイズに合わせてフレームサイズを定義し
#OK・NG各データセットを作成後、結合する

def new_dataset(aug,ok_dir,ng_dir,env_dir):
    #OKNGそれぞれのファイルリストと最大ファイルを取得
    ok_filelist = get_file_list(ok_dir)
    ok_wave_list,ok_largeest_name,ok_largest_size = wav_search(ok_dir,ok_filelist)
    ng_filelist = get_file_list(ng_dir)
    ng_wave_list,ng_largeest_name,ng_largest_size = wav_search(ng_dir,ng_filelist)

    #OKNGの最大を比較
    if ok_largest_size>ng_largest_size:
        largest_dir = ok_dir
        lergest_name = ok_largeest_name
        print("largetst:OK")
    else:
        largest_dir = ng_dir
        lergest_name = ng_largeest_name
        print("largetst:NG")

    #最大フレームサイズを取得
    wf = load_wav(largest_dir,lergest_name)
    frame = int(len(wf))
    #wf = np.insert(wf,frame,np.empty(int(frame*0.2))) #1.2倍する
    #sp_f,sp_t,spg = get_spg(wf) 
    #X_initsize = (len(sp_f),len(sp_t))
    #del wf,sp_f,sp_t,spg
    del wf

    #環境音データをロード
    env_data = load_wav(env_dir,"env.wav")
    
    #OKデータセット作成
    X_ok = copy.deepcopy(
        aug_process(frame,ok_dir,ok_wave_list,env_data)
        )
    y_ok = np.zeros(len(X_ok),dtype = 'bool')   #OKデータをfalse(陰性)と定義

    #NGデータセット作成
    X_ng = copy.deepcopy(
        aug_process(frame,ng_dir,ng_wave_list,env_data)
        )
    y_ng = np.ones(len(X_ng),dtype = 'bool')    #NGデータをTrue(陽性)と定義

    #データセットの結合
    X_data = np.vstack((X_ok,X_ng))
    y_data = np.append(y_ok,y_ng)
    del X_ok,y_ok,X_ng,y_ng

    return X_data,y_data

#OKNGが混在したデータからFalseのみを分離する
def mixed_to_sprit(X_mixed,y_mixed):
    #呼び出されるごとに初期化する
    try:
        X_sprit
    except:
        pass    #X_spritが存在しなければ何もしない
    else:
        del X_sprit #前のデータを消去する

    #y_mixedをboolianindexと見なし、論理値を反転してX_mixedから抽出
    X_sprit = X_mixed[np.logical_not(y_mixed)]

    return X_sprit

###################################メイン処理###################################

#データセット読み込み なければ作る
if os.path.exists(os.path.join(data_dir,datafile)) == False:
    X_data,y_data = new_dataset(aug_amount,ok_dir,ng_dir,env_dir)
    np.savez_compressed(os.path.join(data_dir,datafile),
        X = X_data,y = y_data)
    print("Data set saved!") #ファイルネーム表示機能つけること
else:
    load_data = np.load(os.path.join(data_dir,datafile))
    X_data =load_data['X']
    y_data = load_data['y']
    del load_data
    print("Data loaded!!")

X_shape = X_data.shape[1:]  #データの形状を取得
# Out:
# get file_list :['ok_downsampled_1.wav', 'ok_downsampled_2.wav', 'ok_downsampled_3.wav', 'ok_downsampled_4.wav', 'ok_downsampled_5.wav', 'ok_EQ_1.wav', 'ok_EQ_2.wav', 'ok_EQ_3.wav', 'ok_EQ_4.wav', 'ok_EQ_5.wav', 'ok_noized_1.wav', 'ok_noized_2.wav', 'ok_noized_3.wav', 'ok_noized_4.wav', 'ok_noized_5.wav', 'ok_plain_1.wav', 'ok_plain_2.wav', 'ok_plain_3.wav', 'ok_plain_4.wav', 'ok_plain_5.wav']
# get file :ok_downsampled_4.wav ,file size:341856
# get file_list :['NG_EQ1_1.wav', 'NG_EQ1_2.wav', 'NG_EQ1_3.wav', 'NG_EQ1_4.wav', 'NG_EQ1_5.wav', 'NG_Freqnoize_1.wav', 'NG_Freqnoize_2.wav', 'NG_Freqnoize_3.wav', 'NG_Freqnoize_4.wav', 'NG_Freqnoize_5.wav', 'NG_plane1.wav', 'NG_plane2.wav', 'NG_plane3.wav', 'NG_plane4.wav', 'NG_plane5.wav', 'NG_rezo_1.wav', 'NG_rezo_2.wav', 'NG_rezo_3.wav', 'NG_rezo_4.wav', 'NG_rezo_5.wav']
# get file :NG_EQ1_4.wav ,file size:354888
# largetst:NG
# Augmentation done! total count = 100
# Augmentation done! total count = 200
# Augmentation done! total count = 300
# Augmentation done! total count = 400
# Augmentation done! total count = 500
# Augmentation done! total count = 600
# Augmentation done! total count = 700
# Augmentation done! total count = 800
# Augmentation done! total count = 900
# Augmentation done! total count = 1000
# Augmentation done! total count = 1100
# Augmentation done! total count = 1200
# Augmentation done! total count = 1300
# Augmentation done! total count = 1400
# Augmentation done! total count = 1500
# Augmentation done! total count = 1600
# Augmentation done! total count = 1700
# Augmentation done! total count = 1800
# Augmentation done! total count = 1900
# Augmentation done! total count = 2000
# Augmentation done! total count = 100
# Augmentation done! total count = 200
# Augmentation done! total count = 300
# Augmentation done! total count = 400
# Augmentation done! total count = 500
# Augmentation done! total count = 600
# Augmentation done! total count = 700
# Augmentation done! total count = 800
# Augmentation done! total count = 900
# Augmentation done! total count = 1000
# Augmentation done! total count = 1100
# Augmentation done! total count = 1200
# Augmentation done! total count = 1300
# Augmentation done! total count = 1400
# Augmentation done! total count = 1500
# Augmentation done! total count = 1600
# Augmentation done! total count = 1700
# Augmentation done! total count = 1800
# Augmentation done! total count = 1900
# Augmentation done! total count = 2000
# Data set saved!

# %%
#データ前処理 trainとtestを分離
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = \
    train_test_split(
        X_data.reshape(len(X_data),-1), #アフィン変換
        y_data,
        test_size=0.05)
print(
"Training data amounts :{0}\n\
Test data amounts :{1}"\
.format(len(y_train),len(y_test))
)
del X_data,y_data
# Out:
# Training data amounts :3800
# Test data amounts :200

# %%
#X_trainからOKデータ(False)だけを抽出する
X_train_ae = mixed_to_sprit(X_train,y_train)
print(
"X_train for Autoencoder was splited!!\n\
amount/shape:{0}"
.format(X_train_ae.shape)
)

#スケーラを定義する(AEの出力にシグモイドを使うため)
#scaler = sklearn.preprocessing.MinMaxScaler()
#X_train_ae = scaler.fit_transform(X_train_ae)   #スケール変換
# Out:
# X_train for Autoencoder was splited!!
# amount/shape:(1895, 60021)

# %%
#オートエンコーダの定義

from keras.models import Model,Sequential
from keras.layers import Input, Dense,Dropout,Activation
from keras.layers.normalization import BatchNormalization
from keras import regularizers

#Functionalでの実装
def ae(input_dim,encode_dim,lr,alpha,dr_rate):

    input_data = Input(shape = (input_dim,))

    #エンコーダを定義
    encoder = Dense(
        encode_dim,
        kernel_initializer="he_normal",
        kernel_regularizer=regularizers.l2(alpha),
        )(input_data)
    encoder = BatchNormalization()(encoder)
    encoder = Dropout(dr_rate)(encoder)
    encoder = Activation("relu")(encoder)

    #デコーダを定義 こっちにはドロップアウトは定義しない
    decoder = Dense(input_dim,kernel_initializer="he_normal")(encoder)
    decoder = BatchNormalization()(decoder)
    decoder = Activation("sigmoid")(decoder)

    #モデルを定義
    autoencoder = Model(input = input_data,output = decoder)

    #最適化関数
    opt = keras.optimizers.Nadam(lr = lr)

    autoencoder.compile(
        optimizer = opt,loss='binary_crossentropy',metrics=['accuracy']
        )

    return autoencoder

#コールバック定義 早期打ち切り
def cb_es(monitor):
    x = keras.callbacks.EarlyStopping(monitor = monitor,patience=5)
    return x

#コールバック定義 TensorBordへの出力 バリデーションデータの指定が必須
def cb_tb(log_dir):
    x = keras.callbacks.TensorBoard(
        log_dir=log_dir,
        histogram_freq=1
        )
    return x

    #コールバック定義 自動学習率減衰(もともとNadamは減衰する decay=0.004)
def cb_rd(monitor):
    x = keras.callbacks.ReduceLROnPlateau(
        monitor = monitor,
        factor = 0.1,
        patience = 3,
        verbose= 1,
        min_lr = 1e-08
        )
    return x

#コールバック定義 モデル保存
def cb_cp(modeldir,monitor):
    x = keras.callbacks.ModelCheckpoint(
        filepath = modeldir,
        monitor = monitor,
        save_best_only=True
        )
    return x
# Out:
# Using TensorFlow backend.

# %%
#オートエンコーダの学習
ae = ae(
    input_dim = X_train_ae.shape[1],
    encode_dim = encode_dim,
    lr = lr,
    alpha = alpha,
    dr_rate = dr_rate
)                                       #インスタンス化

#コールバックの定義 今は早期打ち切りしか使ってない
cb_es = cb_es(monitor = monitor)

hist = ae.fit(
    X_train_ae,X_train_ae,
    epochs = epochs,
    batch_size = batch_size,
    callbacks = [cb_es], #,cb_rd,cb_tb うまく動かない
    validation_split = 0.05,
    shuffle = True
)

print('Autoencoder learning is over!')
ae.summary()

#学習曲線の表示
plt.subplot(121)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel("accuracy")
plt.xlabel("epochs")
plt.legend(["Train","test"])
plt.title("Accuracy")

plt.subplot(122)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel("loss")
plt.xlabel("epochs")
plt.legend(["Train","test"])
plt.title("Loss")

plt.show()
# Out:
# Train on 1800 samples, validate on 95 samples
# Epoch 1/100
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.6233 - accuracy: 0.3989 - val_loss: 0.5488 - val_accuracy: 0.3979
# Epoch 2/100
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.4870 - accuracy: 0.4045 - val_loss: 0.4278 - val_accuracy: 0.3979
# Epoch 3/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.3821 - accuracy: 0.4045 - val_loss: 0.3381 - val_accuracy: 0.3979
# Epoch 4/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.3046 - accuracy: 0.4045 - val_loss: 0.2723 - val_accuracy: 0.3979
# Epoch 5/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.2469 - accuracy: 0.4045 - val_loss: 0.2226 - val_accuracy: 0.3979
# Epoch 6/100
# 1800/1800 [==============================] - 61s 34ms/step - loss: 0.2035 - accuracy: 0.4045 - val_loss: 0.1849 - val_accuracy: 0.3979
# Epoch 7/100
# 1800/1800 [==============================] - 53s 30ms/step - loss: 0.1704 - accuracy: 0.4045 - val_loss: 0.1562 - val_accuracy: 0.3979
# Epoch 8/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.1446 - accuracy: 0.4045 - val_loss: 0.1333 - val_accuracy: 0.3979
# Epoch 9/100
# 1800/1800 [==============================] - 65s 36ms/step - loss: 0.1243 - accuracy: 0.4045 - val_loss: 0.1152 - val_accuracy: 0.3979
# Epoch 10/100
# 1800/1800 [==============================] - 65s 36ms/step - loss: 0.1079 - accuracy: 0.4045 - val_loss: 0.1006 - val_accuracy: 0.3979
# Epoch 11/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0947 - accuracy: 0.4045 - val_loss: 0.0888 - val_accuracy: 0.3979
# Epoch 12/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0838 - accuracy: 0.4045 - val_loss: 0.0789 - val_accuracy: 0.3979
# Epoch 13/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0747 - accuracy: 0.4045 - val_loss: 0.0706 - val_accuracy: 0.3979
# Epoch 14/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0670 - accuracy: 0.4045 - val_loss: 0.0635 - val_accuracy: 0.3979
# Epoch 15/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0605 - accuracy: 0.4045 - val_loss: 0.0576 - val_accuracy: 0.3979
# Epoch 16/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0550 - accuracy: 0.4045 - val_loss: 0.0524 - val_accuracy: 0.3979
# Epoch 17/100
# 1800/1800 [==============================] - 62s 34ms/step - loss: 0.0502 - accuracy: 0.4045 - val_loss: 0.0479 - val_accuracy: 0.3979
# Epoch 18/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0460 - accuracy: 0.4045 - val_loss: 0.0440 - val_accuracy: 0.3979
# Epoch 19/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0423 - accuracy: 0.4045 - val_loss: 0.0405 - val_accuracy: 0.3979
# Epoch 20/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0390 - accuracy: 0.4045 - val_loss: 0.0375 - val_accuracy: 0.3979
# Epoch 21/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0362 - accuracy: 0.4045 - val_loss: 0.0348 - val_accuracy: 0.3979
# Epoch 22/100
# 1800/1800 [==============================] - 62s 34ms/step - loss: 0.0336 - accuracy: 0.4045 - val_loss: 0.0324 - val_accuracy: 0.3979
# Epoch 23/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0313 - accuracy: 0.4045 - val_loss: 0.0302 - val_accuracy: 0.3979
# Epoch 24/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0293 - accuracy: 0.4045 - val_loss: 0.0283 - val_accuracy: 0.3979
# Epoch 25/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0274 - accuracy: 0.4045 - val_loss: 0.0265 - val_accuracy: 0.3979
# Epoch 26/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0257 - accuracy: 0.4045 - val_loss: 0.0249 - val_accuracy: 0.3979
# Epoch 27/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0242 - accuracy: 0.4045 - val_loss: 0.0235 - val_accuracy: 0.3979
# Epoch 28/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0228 - accuracy: 0.4045 - val_loss: 0.0221 - val_accuracy: 0.3979
# Epoch 29/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0215 - accuracy: 0.4045 - val_loss: 0.0209 - val_accuracy: 0.3979
# Epoch 30/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0204 - accuracy: 0.4045 - val_loss: 0.0198 - val_accuracy: 0.3979
# Epoch 31/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0193 - accuracy: 0.4045 - val_loss: 0.0188 - val_accuracy: 0.3979
# Epoch 32/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0183 - accuracy: 0.4045 - val_loss: 0.0178 - val_accuracy: 0.3979
# Epoch 33/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0174 - accuracy: 0.4045 - val_loss: 0.0169 - val_accuracy: 0.3979
# Epoch 34/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0165 - accuracy: 0.4045 - val_loss: 0.0161 - val_accuracy: 0.3979
# Epoch 35/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0157 - accuracy: 0.4045 - val_loss: 0.0154 - val_accuracy: 0.3979
# Epoch 36/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0150 - accuracy: 0.4045 - val_loss: 0.0146 - val_accuracy: 0.3979
# Epoch 37/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0143 - accuracy: 0.4045 - val_loss: 0.0140 - val_accuracy: 0.3979
# Epoch 38/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0137 - accuracy: 0.4045 - val_loss: 0.0134 - val_accuracy: 0.3979
# Epoch 39/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0131 - accuracy: 0.4045 - val_loss: 0.0128 - val_accuracy: 0.3979
# Epoch 40/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0125 - accuracy: 0.4045 - val_loss: 0.0123 - val_accuracy: 0.3979
# Epoch 41/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0120 - accuracy: 0.4045 - val_loss: 0.0118 - val_accuracy: 0.3979
# Epoch 42/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0115 - accuracy: 0.4045 - val_loss: 0.0113 - val_accuracy: 0.3979
# Epoch 43/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0111 - accuracy: 0.4045 - val_loss: 0.0108 - val_accuracy: 0.3979
# Epoch 44/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0106 - accuracy: 0.4045 - val_loss: 0.0104 - val_accuracy: 0.3979
# Epoch 45/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0102 - accuracy: 0.4045 - val_loss: 0.0100 - val_accuracy: 0.3979
# Epoch 46/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0098 - accuracy: 0.4045 - val_loss: 0.0096 - val_accuracy: 0.3979
# Epoch 47/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0095 - accuracy: 0.4045 - val_loss: 0.0093 - val_accuracy: 0.3979
# Epoch 48/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0091 - accuracy: 0.4045 - val_loss: 0.0089 - val_accuracy: 0.3979
# Epoch 49/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0088 - accuracy: 0.4045 - val_loss: 0.0086 - val_accuracy: 0.3979
# Epoch 50/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0085 - accuracy: 0.4045 - val_loss: 0.0083 - val_accuracy: 0.3979
# Epoch 51/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0082 - accuracy: 0.4045 - val_loss: 0.0080 - val_accuracy: 0.3979
# Epoch 52/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0079 - accuracy: 0.4045 - val_loss: 0.0077 - val_accuracy: 0.3979
# Epoch 53/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0076 - accuracy: 0.4045 - val_loss: 0.0075 - val_accuracy: 0.3979
# Epoch 54/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0074 - accuracy: 0.4045 - val_loss: 0.0072 - val_accuracy: 0.3979
# Epoch 55/100
# 1800/1800 [==============================] - 65s 36ms/step - loss: 0.0071 - accuracy: 0.4045 - val_loss: 0.0070 - val_accuracy: 0.3979
# Epoch 56/100
# 1800/1800 [==============================] - 66s 36ms/step - loss: 0.0069 - accuracy: 0.4045 - val_loss: 0.0068 - val_accuracy: 0.3979
# Epoch 57/100
# 1800/1800 [==============================] - 62s 34ms/step - loss: 0.0067 - accuracy: 0.4045 - val_loss: 0.0066 - val_accuracy: 0.3979
# Epoch 58/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0064 - accuracy: 0.4045 - val_loss: 0.0063 - val_accuracy: 0.3979
# Epoch 59/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0062 - accuracy: 0.4045 - val_loss: 0.0061 - val_accuracy: 0.3979
# Epoch 60/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0061 - accuracy: 0.4045 - val_loss: 0.0060 - val_accuracy: 0.3979
# Epoch 61/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0059 - accuracy: 0.4045 - val_loss: 0.0058 - val_accuracy: 0.3979
# Epoch 62/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0057 - accuracy: 0.4045 - val_loss: 0.0056 - val_accuracy: 0.3979
# Epoch 63/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0055 - accuracy: 0.4045 - val_loss: 0.0054 - val_accuracy: 0.3979
# Epoch 64/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0054 - accuracy: 0.4045 - val_loss: 0.0053 - val_accuracy: 0.3979
# Epoch 65/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0052 - accuracy: 0.4045 - val_loss: 0.0051 - val_accuracy: 0.3979
# Epoch 66/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0051 - accuracy: 0.4045 - val_loss: 0.0050 - val_accuracy: 0.3979
# Epoch 67/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0049 - accuracy: 0.4045 - val_loss: 0.0048 - val_accuracy: 0.3979
# Epoch 68/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0048 - accuracy: 0.4045 - val_loss: 0.0047 - val_accuracy: 0.3979
# Epoch 69/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0046 - accuracy: 0.4045 - val_loss: 0.0046 - val_accuracy: 0.3979
# Epoch 70/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0045 - accuracy: 0.4045 - val_loss: 0.0044 - val_accuracy: 0.3979
# Epoch 71/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0044 - accuracy: 0.4045 - val_loss: 0.0043 - val_accuracy: 0.3979
# Epoch 72/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0043 - accuracy: 0.4045 - val_loss: 0.0042 - val_accuracy: 0.3979
# Epoch 73/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0042 - accuracy: 0.4045 - val_loss: 0.0041 - val_accuracy: 0.3979
# Epoch 74/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0040 - accuracy: 0.4045 - val_loss: 0.0040 - val_accuracy: 0.3979
# Epoch 75/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0039 - accuracy: 0.4045 - val_loss: 0.0039 - val_accuracy: 0.3979
# Epoch 76/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0038 - accuracy: 0.4045 - val_loss: 0.0038 - val_accuracy: 0.3979
# Epoch 77/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0037 - accuracy: 0.4045 - val_loss: 0.0037 - val_accuracy: 0.3979
# Epoch 78/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0036 - accuracy: 0.4045 - val_loss: 0.0036 - val_accuracy: 0.3979
# Epoch 79/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0035 - accuracy: 0.4045 - val_loss: 0.0035 - val_accuracy: 0.3979
# Epoch 80/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0035 - accuracy: 0.4045 - val_loss: 0.0034 - val_accuracy: 0.3979
# Epoch 81/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0034 - accuracy: 0.4045 - val_loss: 0.0033 - val_accuracy: 0.3979
# Epoch 82/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0033 - accuracy: 0.4045 - val_loss: 0.0032 - val_accuracy: 0.3979
# Epoch 83/100
# 1800/1800 [==============================] - 62s 35ms/step - loss: 0.0032 - accuracy: 0.4045 - val_loss: 0.0032 - val_accuracy: 0.3979
# Epoch 84/100
# 1800/1800 [==============================] - 65s 36ms/step - loss: 0.0031 - accuracy: 0.4045 - val_loss: 0.0031 - val_accuracy: 0.3979
# Epoch 85/100
# 1800/1800 [==============================] - 66s 37ms/step - loss: 0.0031 - accuracy: 0.4045 - val_loss: 0.0030 - val_accuracy: 0.3979
# Epoch 86/100
# 1800/1800 [==============================] - 62s 34ms/step - loss: 0.0030 - accuracy: 0.4045 - val_loss: 0.0029 - val_accuracy: 0.3979
# Epoch 87/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0029 - accuracy: 0.4045 - val_loss: 0.0029 - val_accuracy: 0.3979
# Epoch 88/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0028 - accuracy: 0.4045 - val_loss: 0.0028 - val_accuracy: 0.3979
# Epoch 89/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0028 - accuracy: 0.4045 - val_loss: 0.0027 - val_accuracy: 0.3979
# Epoch 90/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0027 - accuracy: 0.4045 - val_loss: 0.0027 - val_accuracy: 0.3979
# Epoch 91/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0026 - accuracy: 0.4045 - val_loss: 0.0026 - val_accuracy: 0.3979
# Epoch 92/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0026 - accuracy: 0.4045 - val_loss: 0.0026 - val_accuracy: 0.3979
# Epoch 93/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0025 - accuracy: 0.4045 - val_loss: 0.0025 - val_accuracy: 0.3979
# Epoch 94/100
# 1800/1800 [==============================] - 64s 36ms/step - loss: 0.0025 - accuracy: 0.4045 - val_loss: 0.0024 - val_accuracy: 0.3979
# Epoch 95/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0024 - accuracy: 0.4045 - val_loss: 0.0024 - val_accuracy: 0.3979
# Epoch 96/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0024 - accuracy: 0.4045 - val_loss: 0.0023 - val_accuracy: 0.3979
# Epoch 97/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0023 - accuracy: 0.4045 - val_loss: 0.0023 - val_accuracy: 0.3979
# Epoch 98/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0023 - accuracy: 0.4045 - val_loss: 0.0022 - val_accuracy: 0.3979
# Epoch 99/100
# 1800/1800 [==============================] - 64s 35ms/step - loss: 0.0022 - accuracy: 0.4045 - val_loss: 0.0022 - val_accuracy: 0.3979
# Epoch 100/100
# 1800/1800 [==============================] - 63s 35ms/step - loss: 0.0022 - accuracy: 0.4045 - val_loss: 0.0021 - val_accuracy: 0.3979
# Autoencoder learning is over!
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 60021)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               30011000
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 500)               2000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# activation_1 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 60021)             30070521
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 60021)             240084
# _________________________________________________________________
# activation_2 (Activation)    (None, 60021)             0
# =================================================================
# Total params: 60,323,605
# Trainable params: 60,202,563
# Non-trainable params: 121,042
# _________________________________________________________________

# %%
#推論を行う
X_decode = ae.predict(X_test)
print ("Prediction is finished!!")

#%%
#誤差スコアの計算 どちらがいいのかわからないので総和とMSE双方を計算
#総和の差分を計算
diff_score =np.zeros(y_test.shape)
for i in range(X_test.shape[0]):
    diff_score[i] = np.sum(np.abs(X_test[i]-X_decode[i]))
plt.bar(range(10),diff_score[:10],tick_label = y_test[:10],log = True )
plt.show()

#MSEを計算
diff_mse = np.zeros(y_test.shape)
from sklearn.metrics import mean_squared_error
for i in range(X_test.shape[0]):
    diff_mse[i] = mean_squared_error(X_test[i],X_decode[i])
plt.bar(range(10),diff_mse[:10],tick_label = y_test[:10],log = True )
plt.show()
# Out:
# Prediction is finished!!

# %% [markdown]
# 明らかに性能が向上している
# ハイパーパラメータの最適化を行えばさらなる性能向上も見込めそう

# %%
scaler = sklearn.preprocessing.MinMaxScaler()
X_train_ae = scaler.fit_transform(X_train_ae)

# %%
hist = ae.fit(
    X_train_ae,X_train_ae,
    epochs = epochs,
    batch_size = batch_size,
    callbacks = [cb_es], #,cb_rd,cb_tb うまく動かない
    validation_split = 0.05,
    shuffle = True
)

print('Autoencoder learning is over!')
ae.summary()

#学習曲線の表示
plt.subplot(121)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.ylabel("accuracy")
plt.xlabel("epochs")
plt.legend(["Train","test"])
plt.title("Accuracy")

plt.subplot(122)
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.ylabel("loss")
plt.xlabel("epochs")
plt.legend(["Train","test"])
plt.title("Loss")

plt.show()

#%%
#推論を行う
X_decode = ae.predict(scaler.transform(X_test))
print ("Prediction is finished!!")

#%%
#誤差スコアの計算 どちらがいいのかわからないので総和とMSE双方を計算
#総和の差分を計算
diff_score =np.zeros(y_test.shape)
for i in range(X_test.shape[0]):
    diff_score[i] = np.sum(np.abs(X_test[i]-X_decode[i]))
plt.bar(range(10),diff_score[:10],tick_label = y_test[:10],log = True )
plt.show()

#MSEを計算
diff_mse = np.zeros(y_test.shape)
from sklearn.metrics import mean_squared_error
for i in range(X_test.shape[0]):
    diff_mse[i] = mean_squared_error(X_test[i],X_decode[i])
plt.bar(range(10),diff_mse[:10],tick_label = y_test[:10],log = True )
plt.show()
# Out:
# Train on 1800 samples, validate on 95 samples
# Epoch 1/100
#  900/1800 [==============>...............] - ETA: 30s - loss: nan - accuracy: 0.0000e+00
