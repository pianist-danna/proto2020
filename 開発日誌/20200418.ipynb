# %%
"""
Tensorflowによるオートエンコーダの実装
思い出しがてらの作成なのでコメントが膨大…
"""


#%%
# cording = UTF-8
import os
import re
import random
import copy
import scipy
import librosa #無くしたい
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import keras
import tensorflow

####################################初期化####################################
aug_amount = 100    #ファイルごとのAugmentationの回数
lr = 1e-01          #初期学習率
alpha = 1e-03       #L2正則化の係数
dr_rate = 0.3       #ドロップアウト率
batch_size = 50
epochs = 100
encode_dim = 1000   #オートエンコーダの圧縮次元

#ディレクトリの初期化
base_dir = "../"
data_dir =os.path.join(base_dir,"data")
ok_dir = os.path.join(data_dir,"OK")
ng_dir = os.path.join(data_dir,"NG")
env_dir = os.path.join(data_dir,"environment")

#学習用データファイル
datafile = "dataset2.npz"

####################################関数定義###################################

#対象ディレクトリのファイル一覧を取得
def get_file_list(dir):
    path = dir
    file_list = os.listdir(path)
    print("get file_list :{}".format(file_list))
    return file_list

#対象ディレクトリの最大ファイルをサーチ
def wav_search(dir,f_list):
    #呼び出されるごとに初期化する
    wave_list = []
    file_size = 0
    
    return_path = os.path.abspath('./')
    
    os.chdir(dir)
    for i in f_list:
        search_index = re.search('.wav',i)
        if search_index:
            wave_list .append(i)
            if os.path.getsize(i) > file_size:
                file_size = os.path.getsize(i)
                largest_file = i
        
    os.chdir(return_path)   #カレントディレクトリを戻す
    print("get file :{0} ,file size:{1}"\
        .format(largest_file,file_size))
    return wave_list,largest_file,file_size

#オーディオファイルの読み込み サンプルレート22.05kHz、モノラルで固定
def load_wav(dir,file):
    #呼び出されるごとに初期化する
    wf = np.arange(0)

    f_path = os.path.join(dir,file)
    wf,sp_rate = librosa.load(f_path,sr=22050,mono = True)
    del sp_rate
    return wf

#スペクトログラムの取得 パワースペクトラムのまま処理するならlibrosa不要
def get_spg(wf):
    spg = np.arange(0)
    sp_f,sp_t,spg = scipy.signal.spectrogram(wf,fs=22050,
        window = np.hamming(1024),nfft =1024)
    spg = librosa.power_to_db(spg)
    spg =spg.astype('float16')
    return sp_f,sp_t,spg

#Augmentationの処理
def aug_process(frame,dir,wave_list,env_file,):
    #呼び出されるごとに初期化する
    length = 0
    count = 0
    wf = np.arange(0)

    length = int(frame * 1.2)
    for i in wave_list:
        wf = load_wav(dir,i)
        for j in range(aug_amount):
            start = random.randint(0,len(env_file)-length)
            aug_wav = copy.deepcopy(env_file[start : start + length])
            del start
            start = random.randint(0,len(aug_wav) - len(wf))
            aug_wav = aug_wav + random.gauss(1,0.05)
            aug_wav[ start:start + len(wf) ] = \
                aug_wav[ start : start + len(wf) ] + wf
            sp_f,sp_t,spg = get_spg(aug_wav)
            spg = spg.reshape(1,len(sp_f),len(sp_t))
            try:
                X_data
            except:
                X_data = copy.deepcopy(spg)
            else:
                X_data = np.vstack((X_data,spg))
            del start,aug_wav,sp_f,sp_t,spg
            count = count + 1
        del wf
        print("Augmentation done! total count = {}".format(count))

    return X_data

#データセットの作成 ここまでの関数は全部ここに集約される
#最大ファイルサイズに合わせてフレームサイズを定義し
#OK・NG各データセットを作成後、結合する

def new_dataset(aug,ok_dir,ng_dir,env_dir):
    #OKNGそれぞれのファイルリストと最大ファイルを取得
    ok_filelist = get_file_list(ok_dir)
    ok_wave_list,ok_largeest_name,ok_largest_size = wav_search(ok_dir,ok_filelist)
    ng_filelist = get_file_list(ng_dir)
    ng_wave_list,ng_largeest_name,ng_largest_size = wav_search(ng_dir,ng_filelist)

    #OKNGの最大を比較
    if ok_largest_size>ng_largest_size:
        largest_dir = ok_dir
        lergest_name = ok_largeest_name
        print("largetst:OK")
    else:
        largest_dir = ng_dir
        lergest_name = ng_largeest_name
        print("largetst:NG")

    #最大フレームサイズを取得
    wf = load_wav(largest_dir,lergest_name)
    frame = int(len(wf))
    #wf = np.insert(wf,frame,np.empty(int(frame*0.2))) #1.2倍する
    #sp_f,sp_t,spg = get_spg(wf) 
    #X_initsize = (len(sp_f),len(sp_t))
    #del wf,sp_f,sp_t,spg
    del wf

    #環境音データをロード
    env_data = load_wav(env_dir,"env.wav")
    
    #OKデータセット作成
    X_ok = copy.deepcopy(
        aug_process(frame,ok_dir,ok_wave_list,env_data)
        )
    y_ok = np.zeros(len(X_ok),dtype = 'bool')

    #NGデータセット作成
    X_ng = copy.deepcopy(
        aug_process(frame,ng_dir,ng_wave_list,env_data)
        )
    y_ng = np.ones(len(X_ng),dtype = 'bool')

    #データセットの結合
    X_data = np.vstack((X_ok,X_ng))
    y_data = np.append(y_ok,y_ng)
    del X_ok,y_ok,X_ng,y_ng

    return X_data,y_data

#OKNGが混在したデータからFalseのみを分離する
def mixed_to_sprit(X_mixed,y_mixed):
    #呼び出されるごとに初期化する
    try:
        X_sprit
    except:
        pass    #X_spritが存在しなければ何もしない
    else:
        del X_sprit #前のデータを消去する

    for i in range(len(X_mixed)):
        if y_mixed[i] == False:
            try:
                X_sprit
            except: #X_spritを生成する
                X_sprit = copy.deepcopy(X_mixed[i])
                X_sprit = X_sprit.reshape(1,X_mixed.shape[1])
            else:   #既存のX_spritに追加する 前段の例外処理はここを避けるため
                X_sprit = np.vstack(
                    (X_sprit,X_mixed[i].reshape(1,X_mixed.shape[1]))
                    )

    return X_sprit

###################################メイン処理###################################

#データセット読み込み なければ作る
if os.path.exists(os.path.join(data_dir,datafile)) == False:
    X_data,y_data = new_dataset(aug_amount,ok_dir,ng_dir,env_dir)
    np.savez_compressed(os.path.join(data_dir,datafile),
        X = X_data,y = y_data)
    print("Data set saved!") #ファイルネーム表示機能つけること
else:
    load_data = np.load(os.path.join(data_dir,datafile))
    X_data =load_data['X']
    y_data = load_data['y']
    del load_data
    print("Data loaded!!")

#データ前処理 trainとtestを分離
from sklearn.model_selection import train_test_split
X_shape = X_data.shape[1:]
X_data = X_data.reshape(len(X_data),-1) #アフィン変換
X_train,X_test,y_train,y_test = \
    train_test_split(X_data,y_data,test_size=0.05)
print(
"Training data amounts :{0}\n\
Test data amounts :{1}"\
.format(len(y_train),len(y_test))
)
del X_data,y_data
# Out:
# Using TensorFlow backend.
# Data loaded!!
# Training data amounts :3800
# Test data amounts :200

# %%
#X_trainからOKデータ(False)だけを抽出する

X_train_ae = mixed_to_sprit(X_train,y_train)
print(
"X_train for Autoencoder was splited!!\n\
amount/shape:{0}"
.format(X_train_ae.shape)
)

#スケーラを定義する(AEの出力にシグモイドを使うため)
scaler = sklearn.preprocessing.MinMaxScaler()
# Out:
# X_train for Autoencoder was splited!!
# amount/shape:(1906, 60021)

# %%
#オートエンコーダの定義

from keras.models import Model,Sequential
from keras.layers import Input, Dense,Dropout,Activation
from keras.layers.normalization import BatchNormalization
from keras import regularizers

#Modelでの実装 もう少しわかりやすい形にする
def ae(input_dim,encode_dim,lr,alpha,dr_rate):

    input_data = Input(shape = (input_dim,))

    #エンコーダを定義
    encoder = Dense(
        encode_dim,
        kernel_initializer="he_normal",
        kernel_regularizer=regularizers.l2(alpha),
        )(input_data)
    encoder = BatchNormalization()(encoder)
    encoder = Dropout(dr_rate)(encoder)
    encoder = Activation("relu")(encoder)

    #デコーダを定義 こっちにはドロップアウトは定義しない
    decoder = Dense(input_dim,kernel_initializer="he_normal")(encoder)
    decoder = BatchNormalization()(decoder)
    decoder = Activation("sigmoid")(decoder)

    #モデルを定義
    autoencoder = Model(input = input_data,output = decoder)

    #最適化関数 Nadamをデフォルトパラメタで使う
    opt = keras.optimizers.nadam(lr = lr)

    autoencoder.compile(
        optimizer = opt,loss='binary_crossentropy',metrics=['accuracy']
        )

    return autoencoder

# %%
# グリッドサーチ用コード

# パラメータ空間の定義
def gs_param():
    pm = {
        'alpha' : [1,1e-02,1e-04,1e-06],
        'lr':[1,0.1,0.01,1e-03],
        'dr_rate':[0.2],
        'batch_size':[50],
        'epochs':[10]
    }
    return pm

#SklearnでラップしたAEを生成
from keras.wrappers.scikit_learn import KerasClassifier
ae_sklearn = KerasClassifier(
    build_fn = ae,
    input_dim = X_train_ae.shape[1],
    encode_dim = encode_dim,
    lr = lr,
    alpha = alpha,
    dr_rate = dr_rate
)

#グリッドサーチ
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(
    estimator = ae_sklearn,
    param_grid = gs_param(),
    return_train_score = True,
    cv = 3,
    verbose = 2 
)
X_train_ae = scaler.fit_transform(X_train_ae)   #スケール変換
grid.fit(X_train_ae,X_train_ae)

#レポートの表示
print('Gridsearch is over!')
print("Best parameters :{}".format(grid.best_params_))
print("Best cross-validation score :{}".format(grid.best_score_))

#テスト結果の一覧表示(データフレーム使用)
import pandas as pd
results = pd.DataFrame(grid.cv_results_)
display(results)

#Dropout = 0.2の時のヒートマップを描画
pm = gs_param()
npresult = np.array(grid.cv_results_['mean_test_score']).reshape(4,4)
plt.pcolormesh(npresult)
plt.title('2nd Gridsearch')
plt.xlabel("alpha")
plt.xticks(np.arange(len(pm['alpha'])),pm['alpha'])
plt.ylabel("Larning Rate")
plt.yticks(np.arange(len(pm['lr'])),pm['lr'])
plt.colorbar()
plt.show()
# Out:
# - 74s 58ms/step - loss: 0.7016 - accuracy: 0.0254
# Epoch 9/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 0.6977 - accuracy: 0.0260
# Epoch 10/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 0.6948 - accuracy: 0.0265
# 636/636 [==============================] - 4s 7ms/step
# 1270/1270 [==============================] - 8s 7ms/step
# [CV]  alpha=0.0001, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001, total=12.5min
# [CV] alpha=0.0001, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001 ...
# Epoch 1/10
# 1271/1271 [==============================] - 74s 59ms/step - loss: 0.8117 - accuracy: 0.0195
# Epoch 2/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 0.7394 - accuracy: 0.0210
# Epoch 3/10
# 1271/1271 [==============================] - 74s 58ms/step - loss: 0.7301 - accuracy: 0.0221
# Epoch 4/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7220 - accuracy: 0.0230
# Epoch 5/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7157 - accuracy: 0.0237
# Epoch 6/10
# 1271/1271 [==============================] - 74s 58ms/step - loss: 0.7107 - accuracy: 0.0242
# Epoch 7/10
# 1271/1271 [==============================] - 74s 58ms/step - loss: 0.7062 - accuracy: 0.0248
# Epoch 8/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7024 - accuracy: 0.0254
# Epoch 9/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.6977 - accuracy: 0.0261
# Epoch 10/10
# 1271/1271 [==============================] - 74s 58ms/step - loss: 0.6939 - accuracy: 0.0265
# 635/635 [==============================] - 5s 7ms/step
# 1271/1271 [==============================] - 8s 7ms/step
# [CV]  alpha=0.0001, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001, total=12.5min
# [CV] alpha=0.0001, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001 ...
# Epoch 1/10
# 1271/1271 [==============================] - 76s 59ms/step - loss: 0.8140 - accuracy: 0.0195
# Epoch 2/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7387 - accuracy: 0.0212
# Epoch 3/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7293 - accuracy: 0.0222
# Epoch 4/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 0.7227 - accuracy: 0.0231
# Epoch 5/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7160 - accuracy: 0.0238
# Epoch 6/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7112 - accuracy: 0.0244
# Epoch 7/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7062 - accuracy: 0.0249
# Epoch 8/10
# 1271/1271 [==============================] - 74s 59ms/step - loss: 0.7021 - accuracy: 0.0254
# Epoch 9/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.6981 - accuracy: 0.0259
# Epoch 10/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.6944 - accuracy: 0.0264
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 9s 7ms/step
# [CV]  alpha=0.0001, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001, total=12.5min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=1 ........
# Epoch 1/10
# 1270/1270 [==============================] - 79s 62ms/step - loss: 3.8934 - accuracy: 0.0307
# Epoch 2/10
# 1270/1270 [==============================] - 76s 60ms/step - loss: 2.4744 - accuracy: 0.0306
# Epoch 3/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 2.8727 - accuracy: 0.0308
# Epoch 4/10
# 1270/1270 [==============================] - 74s 59ms/step - loss: 3.4400 - accuracy: 0.0311
# Epoch 5/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 3.3147 - accuracy: 0.0311
# Epoch 6/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 3.4591 - accuracy: 0.0311
# Epoch 7/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 3.4071 - accuracy: 0.0312
# Epoch 8/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 3.5211 - accuracy: 0.0313
# Epoch 9/10
# 1270/1270 [==============================] - 76s 60ms/step - loss: 3.7435 - accuracy: 0.0315
# Epoch 10/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 3.5184 - accuracy: 0.0316
# 636/636 [==============================] - 6s 9ms/step
# 1270/1270 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=1, total=12.7min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=1 ........
# Epoch 1/10
# 1271/1271 [==============================] - 78s 62ms/step - loss: 5.9878 - accuracy: 0.0306
# Epoch 2/10
# 1271/1271 [==============================] - 79s 62ms/step - loss: 1.5481 - accuracy: 0.0305
# Epoch 3/10
# 1271/1271 [==============================] - 77s 60ms/step - loss: 2.6266 - accuracy: 0.0307
# Epoch 4/10
# 1271/1271 [==============================] - 79s 62ms/step - loss: 3.0951 - accuracy: 0.0306
# Epoch 5/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.4073 - accuracy: 0.0309
# Epoch 6/10
# 1271/1271 [==============================] - 76s 60ms/step - loss: 3.3731 - accuracy: 0.0308
# Epoch 7/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.4794 - accuracy: 0.0311
# Epoch 8/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.5420 - accuracy: 0.0314
# Epoch 9/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.3974 - accuracy: 0.0315
# Epoch 10/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.6322 - accuracy: 0.0315
# 635/635 [==============================] - 5s 7ms/step
# 1271/1271 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=1, total=13.5min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=1 ........
# Epoch 1/10
# 1271/1271 [==============================] - 77s 61ms/step - loss: 3.8737 - accuracy: 0.0304
# Epoch 2/10
# 1271/1271 [==============================] - 74s 58ms/step - loss: 2.4460 - accuracy: 0.0305
# Epoch 3/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 2.9193 - accuracy: 0.0306
# Epoch 4/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.3075 - accuracy: 0.0307
# Epoch 5/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.4105 - accuracy: 0.0308
# Epoch 6/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 3.5893 - accuracy: 0.0309
# Epoch 7/10
# 1271/1271 [==============================] - 74s 59ms/step - loss: 3.4718 - accuracy: 0.0311
# Epoch 8/10
# 1271/1271 [==============================] - 74s 59ms/step - loss: 3.4910 - accuracy: 0.0312
# Epoch 9/10
# 1271/1271 [==============================] - 76s 60ms/step - loss: 3.6716 - accuracy: 0.0314
# Epoch 10/10
# 1271/1271 [==============================] - 74s 59ms/step - loss: 3.4734 - accuracy: 0.0314
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=1, total=13.0min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.1 ......
# Epoch 1/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 0.8499 - accuracy: 0.0306
# Epoch 2/10
# 1270/1270 [==============================] - 76s 60ms/step - loss: 0.6589 - accuracy: 0.0336
# Epoch 3/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 0.6597 - accuracy: 0.0336
# Epoch 4/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 0.6614 - accuracy: 0.0337
# Epoch 5/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 0.6596 - accuracy: 0.0337
# Epoch 6/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 0.6609 - accuracy: 0.0337
# Epoch 7/10
# 1270/1270 [==============================] - 74s 59ms/step - loss: 0.6615 - accuracy: 0.0337
# Epoch 8/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 0.6622 - accuracy: 0.0337
# Epoch 9/10
# 1270/1270 [==============================] - 72s 57ms/step - loss: 0.6613 - accuracy: 0.0337
# Epoch 10/10
# 1270/1270 [==============================] - 73s 57ms/step - loss: 0.6614 - accuracy: 0.0337
# 636/636 [==============================] - 4s 7ms/step
# 1270/1270 [==============================] - 8s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.1, total=12.5min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.1 ......
# Epoch 1/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.8389 - accuracy: 0.0306
# Epoch 2/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6586 - accuracy: 0.0335
# Epoch 3/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6589 - accuracy: 0.0335
# Epoch 4/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.6598 - accuracy: 0.0335
# Epoch 5/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6613 - accuracy: 0.0335
# Epoch 6/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6616 - accuracy: 0.0336
# Epoch 7/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6618 - accuracy: 0.0335
# Epoch 8/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6620 - accuracy: 0.0336
# Epoch 9/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.6621 - accuracy: 0.0336
# Epoch 10/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6640 - accuracy: 0.0336
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 8s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.1, total=12.2min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.1 ......
# Epoch 1/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.8389 - accuracy: 0.0304
# Epoch 2/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.6578 - accuracy: 0.0333
# Epoch 3/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6585 - accuracy: 0.0333
# Epoch 4/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6604 - accuracy: 0.0333
# Epoch 5/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6613 - accuracy: 0.0333
# Epoch 6/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6605 - accuracy: 0.0334
# Epoch 7/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.6614 - accuracy: 0.0334
# Epoch 8/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6621 - accuracy: 0.0334
# Epoch 9/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6626 - accuracy: 0.0334
# Epoch 10/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6618 - accuracy: 0.0334
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 8s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.1, total=12.1min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.01 .....
# Epoch 1/10
# 1270/1270 [==============================] - 73s 57ms/step - loss: 0.7307 - accuracy: 0.0228
# Epoch 2/10
# 1270/1270 [==============================] - 74s 58ms/step - loss: 0.6795 - accuracy: 0.0284
# Epoch 3/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6596 - accuracy: 0.0324
# Epoch 4/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6517 - accuracy: 0.0338
# Epoch 5/10
# 1270/1270 [==============================] - 72s 57ms/step - loss: 0.6482 - accuracy: 0.0341
# Epoch 6/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6465 - accuracy: 0.0342
# Epoch 7/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6450 - accuracy: 0.0342
# Epoch 8/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6445 - accuracy: 0.0342
# Epoch 9/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6435 - accuracy: 0.0342
# Epoch 10/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6432 - accuracy: 0.0343
# 636/636 [==============================] - 5s 7ms/step
# 1270/1270 [==============================] - 8s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.01, total=12.2min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.01 .....
# Epoch 1/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7356 - accuracy: 0.0224
# Epoch 2/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6811 - accuracy: 0.0287
# Epoch 3/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6599 - accuracy: 0.0325
# Epoch 4/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6521 - accuracy: 0.0337
# Epoch 5/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6482 - accuracy: 0.0340
# Epoch 6/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6464 - accuracy: 0.0340
# Epoch 7/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6450 - accuracy: 0.0341
# Epoch 8/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6443 - accuracy: 0.0341
# Epoch 9/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6438 - accuracy: 0.0341
# Epoch 10/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6433 - accuracy: 0.0341
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.01, total=12.1min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.01 .....
# Epoch 1/10
# 1271/1271 [==============================] - 73s 58ms/step - loss: 0.7308 - accuracy: 0.0222
# Epoch 2/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6796 - accuracy: 0.0281
# Epoch 3/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6597 - accuracy: 0.0321
# Epoch 4/10
# 1271/1271 [==============================] - 71s 56ms/step - loss: 0.6514 - accuracy: 0.0335
# Epoch 5/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6477 - accuracy: 0.0338
# Epoch 6/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6461 - accuracy: 0.0339
# Epoch 7/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6447 - accuracy: 0.0339
# Epoch 8/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6440 - accuracy: 0.0339
# Epoch 9/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6434 - accuracy: 0.0339
# Epoch 10/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6427 - accuracy: 0.0339
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.01, total=12.2min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001 ....
# Epoch 1/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 0.7564 - accuracy: 0.0195
# Epoch 2/10
# 1270/1270 [==============================] - 73s 58ms/step - loss: 0.7296 - accuracy: 0.0212
# Epoch 3/10
# 1270/1270 [==============================] - 73s 57ms/step - loss: 0.7169 - accuracy: 0.0226
# Epoch 4/10
# 1270/1270 [==============================] - 73s 58ms/step - loss: 0.7082 - accuracy: 0.0236
# Epoch 5/10
# 1270/1270 [==============================] - 75s 59ms/step - loss: 0.7016 - accuracy: 0.0244
# Epoch 6/10
# 1270/1270 [==============================] - 72s 57ms/step - loss: 0.6953 - accuracy: 0.0252
# Epoch 7/10
# 1270/1270 [==============================] - 72s 56ms/step - loss: 0.6897 - accuracy: 0.0258
# Epoch 8/10
# 1270/1270 [==============================] - 71s 56ms/step - loss: 0.6848 - accuracy: 0.0264
# Epoch 9/10
# 1270/1270 [==============================] - 72s 56ms/step - loss: 0.6803 - accuracy: 0.0270
# Epoch 10/10
# 1270/1270 [==============================] - 73s 58ms/step - loss: 0.6759 - accuracy: 0.0277
# 636/636 [==============================] - 5s 7ms/step
# 1270/1270 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001, total=12.3min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001 ....
# Epoch 1/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7584 - accuracy: 0.0198
# Epoch 2/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.7307 - accuracy: 0.0215
# Epoch 3/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7182 - accuracy: 0.0227
# Epoch 4/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7088 - accuracy: 0.0237
# Epoch 5/10
# 1271/1271 [==============================] - 74s 58ms/step - loss: 0.7019 - accuracy: 0.0245
# Epoch 6/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6955 - accuracy: 0.0253
# Epoch 7/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6906 - accuracy: 0.0258
# Epoch 8/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.6852 - accuracy: 0.0265
# Epoch 9/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6810 - accuracy: 0.0271
# Epoch 10/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6770 - accuracy: 0.0276
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 9s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001, total=12.3min
# [CV] alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001 ....
# Epoch 1/10
# 1271/1271 [==============================] - 75s 59ms/step - loss: 0.7574 - accuracy: 0.0197
# Epoch 2/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7289 - accuracy: 0.0214
# Epoch 3/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7171 - accuracy: 0.0228
# Epoch 4/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7085 - accuracy: 0.0238
# Epoch 5/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.7021 - accuracy: 0.0244
# Epoch 6/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6958 - accuracy: 0.0252
# Epoch 7/10
# 1271/1271 [==============================] - 72s 57ms/step - loss: 0.6900 - accuracy: 0.0261
# Epoch 8/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6857 - accuracy: 0.0265
# Epoch 9/10
# 1271/1271 [==============================] - 72s 56ms/step - loss: 0.6808 - accuracy: 0.0272
# Epoch 10/10
# 1271/1271 [==============================] - 73s 57ms/step - loss: 0.6769 - accuracy: 0.0277
# 635/635 [==============================] - 4s 7ms/step
# 1271/1271 [==============================] - 8s 7ms/step
# [CV]  alpha=1e-06, batch_size=50, dr_rate=0.2, epochs=10, lr=0.001, total=12.3min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 612.2min finished
# Epoch 1/10
# 1906/1906 [==============================] - 110s 58ms/step - loss: 4.5207 - accuracy: 0.0311
# Epoch 2/10
# 1906/1906 [==============================] - 107s 56ms/step - loss: 2.3538 - accuracy: 0.0315
# Epoch 3/10
# 1906/1906 [==============================] - 108s 57ms/step - loss: 3.1616 - accuracy: 0.0320
# Epoch 4/10
# 1906/1906 [==============================] - 109s 57ms/step - loss: 3.2500 - accuracy: 0.0323
# Epoch 5/10
# 1906/1906 [==============================] - 108s 57ms/step - loss: 3.3154 - accuracy: 0.0322
# Epoch 6/10
# 1906/1906 [==============================] - 109s 57ms/step - loss: 3.7276 - accuracy: 0.0323
# Epoch 7/10
# 1906/1906 [==============================] - 108s 57ms/step - loss: 3.5703 - accuracy: 0.0322
# Epoch 8/10
# 1906/1906 [==============================] - 108s 56ms/step - loss: 3.3979 - accuracy: 0.0322
# Epoch 9/10
# 1906/1906 [==============================] - 108s 57ms/step - loss: 3.2826 - accuracy: 0.0323
# Epoch 10/10
# 1906/1906 [==============================] - 108s 57ms/step - loss: 3.4415 - accuracy: 0.0321
# Gridsearch is over!
# Best parameters :{'alpha': 1e-06, 'batch_size': 50, 'dr_rate': 0.2, 'epochs': 10, 'lr': 1}
# Best cross-validation score :0.6869201262791952
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0      801.896505     24.664374         5.738792        0.034534           1
# 1      775.916417      3.289723         5.379197        0.036599           1
# 2      751.260619      8.632709         5.617918        0.504535           1
# 3      754.391774      8.653463         5.328201        0.036846           1
# 4      739.980095     10.503376         5.495907        0.130100        0.01
# 5      740.439518      2.849682         5.375291        0.038535        0.01
# 6      738.433308      6.983585         5.676931        0.344006        0.01
# 7      739.399995      0.879664         5.381984        0.027380        0.01
# 8      746.332937      3.703776         6.290937        0.418394      0.0001
# 9      744.649197      5.300822         5.759692        0.455836      0.0001
# 10     742.814514      2.363377         6.148083        0.447209      0.0001
# 11     742.844363      1.283401         5.623330        0.160509      0.0001
# 12     776.594512     18.652620         7.019114        0.822558       1e-06
# 13     730.919104     11.704415         5.477936        0.058520       1e-06
# 14     722.476309      1.562104         5.795290        0.366551       1e-06
# 15     731.410119      1.747861         5.695555        0.034491       1e-06
#
#    param_batch_size param_dr_rate param_epochs param_lr  \
# 0                50           0.2           10        1
# 1                50           0.2           10      0.1
# 2                50           0.2           10     0.01
# 3                50           0.2           10    0.001
# 4                50           0.2           10        1
# 5                50           0.2           10      0.1
# 6                50           0.2           10     0.01
# 7                50           0.2           10    0.001
# 8                50           0.2           10        1
# 9                50           0.2           10      0.1
# 10               50           0.2           10     0.01
# 11               50           0.2           10    0.001
# 12               50           0.2           10        1
# 13               50           0.2           10      0.1
# 14               50           0.2           10     0.01
# 15               50           0.2           10    0.001
#
#                                                params  ...  split1_test_score  \
# 0   {'alpha': 1, 'batch_size': 50, 'dr_rate': 0.2,...  ...           0.467017
# 1   {'alpha': 1, 'batch_size': 50, 'dr_rate': 0.2,...  ...           0.710127
# 2   {'alpha': 1, 'batch_size': 50, 'dr_rate': 0.2,...  ...           0.345598
# 3   {'alpha': 1, 'batch_size': 50, 'dr_rate': 0.2,...  ...           0.847636
# 4   {'alpha': 0.01, 'batch_size': 50, 'dr_rate': 0...  ...           0.563978
# 5   {'alpha': 0.01, 'batch_size': 50, 'dr_rate': 0...  ...           0.408409
# 6   {'alpha': 0.01, 'batch_size': 50, 'dr_rate': 0...  ...           0.488382
# 7   {'alpha': 0.01, 'batch_size': 50, 'dr_rate': 0...  ...           0.454315
# 8   {'alpha': 0.0001, 'batch_size': 50, 'dr_rate':...  ...           0.662841
# 9   {'alpha': 0.0001, 'batch_size': 50, 'dr_rate':...  ...           0.505818
# 10  {'alpha': 0.0001, 'batch_size': 50, 'dr_rate':...  ...           0.641580
# 11  {'alpha': 0.0001, 'batch_size': 50, 'dr_rate':...  ...           0.255383
# 12  {'alpha': 1e-06, 'batch_size': 50, 'dr_rate': ...  ...           0.727292
# 13  {'alpha': 1e-06, 'batch_size': 50, 'dr_rate': ...  ...           0.614310
# 14  {'alpha': 1e-06, 'batch_size': 50, 'dr_rate': ...  ...           0.566100
# 15  {'alpha': 1e-06, 'batch_size': 50, 'dr_rate': ...  ...           0.399232
#
#     split2_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0            0.603298         0.525328        0.057347                8
# 1            0.542145         0.635762        0.069917                2
# 2            0.273310         0.303291        0.030772               15
# 3            0.312865         0.511832        0.238800               10
# 4            0.635108         0.616437        0.037604                3
# 5            0.155076         0.266400        0.105674               16
# 6            0.832246         0.608523        0.158340                6
# 7            0.256661         0.378927        0.087235               12
# 8            0.430472         0.516246        0.104158                9
# 9            0.458121         0.467944        0.027796               11
# 10           0.684638         0.615332        0.069816                5
# 11           0.505795         0.366437        0.104171               13
# 12           0.613967         0.686920        0.051683                1
# 13           0.437218         0.548371        0.079051                7
# 14           0.573347         0.615858        0.065311                4
# 15           0.309693         0.332022        0.048409               14
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.506112            0.466904            0.601571
# 1             0.656463            0.710790            0.539804
# 2             0.291921            0.345759            0.272370
# 3             0.375218            0.847875            0.312269
# 4             0.650464            0.564056            0.634396
# 5             0.236096            0.408100            0.154360
# 6             0.506556            0.488235            0.831963
# 7             0.424844            0.454054            0.257696
# 8             0.455751            0.662907            0.429869
# 9             0.440493            0.505924            0.457200
# 10            0.517990            0.641217            0.684594
# 11            0.336532            0.255571            0.509975
# 12            0.719910            0.727524            0.613309
# 13            0.593402            0.613966            0.437635
# 14            0.706516            0.565242            0.576357
# 15            0.287440            0.397770            0.318422
#
#     mean_train_score  std_train_score
# 0           0.524862         0.056554
# 1           0.635686         0.071334
# 2           0.303350         0.031032
# 3           0.511787         0.239035
# 4           0.616306         0.037524
# 5           0.266185         0.105751
# 6           0.608918         0.157894
# 7           0.378865         0.086505
# 8           0.516176         0.104291
# 9           0.467872         0.027757
# 10          0.614600         0.070572
# 11          0.367359         0.106123
# 12          0.686914         0.052140
# 13          0.548334         0.078725
# 14          0.616038         0.064138
# 15          0.334544         0.046462
#
# [16 rows x 21 columns]

# %%
#Dropout = 0.2の時のヒートマップを描画
pm = gs_param()
npresult = np.array(grid.cv_results_['mean_test_score']).reshape(4,4)
plt.pcolormesh(npresult)
plt.title('2nd Gridsearch')
plt.ylabel("alpha")
plt.yticks(np.arange(len(pm['alpha'])),pm['alpha'])
plt.xlabel("Larning Rate")
plt.xticks(np.arange(len(pm['lr'])),pm['lr'])
plt.colorbar()
plt.show()

# %% [markdown]
# 結果だけ見るとlr=1の結果が良好だがLossが比較的高く、lr0.01～0.001がloss,accuracyとも安定している
